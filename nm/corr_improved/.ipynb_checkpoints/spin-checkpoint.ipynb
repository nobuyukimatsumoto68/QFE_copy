# %%
import numpy as np
import numpy as np
import matplotlib.pyplot as plt

import scipy as sp
import scipy.linalg
import scipy.optimize

import os

# %%
spin=np.loadtxt("spin.dat")

# %%
plt.matshow(spin)

# %%
plt.contour(spin, [0,1])

# %%
cluster=np.loadtxt("clusters.dat")

# %%
plt.matshow( cluster )
plt.savefig("cluster.pdf")
plt.matshow( spin )
plt.savefig("spin.pdf")

# %%
plt.contour(cluster, np.arange(np.max(cluster)))

# %%
plt.matshow(cluster)
