# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
Lx=64
Ly=64

# %%
directory="./ising_t2/"
ensemble_id="64_64_1.000_1.000_0.000"

# %%
s_s_mean=np.loadtxt(directory+ensemble_id+"_s_s_mean.dat")
s_s_err =np.loadtxt(directory+ensemble_id+"_s_s_err.dat")

# %%
plt.matshow(np.log(s_s_mean))

# %%
ex_ex_mean=np.loadtxt(directory+ensemble_id+"_ex_ex_mean.dat")
ex_ex_err =np.loadtxt(directory+ensemble_id+"_ex_ex_err.dat")

# %%
plt.matshow(np.log(ex_ex_mean))

# %%
plt.errorbar(np.arange(Lx), ex_ex_mean[0], ex_ex_err[0])
plt.yscale("log")

# %%
ex_ey_mean=np.loadtxt(directory+ensemble_id+"_ex_ey_mean.dat")
ex_ey_err =np.loadtxt(directory+ensemble_id+"_ex_ey_err.dat")

# %%
plt.matshow(np.log(ex_ey_mean))

# %%
plt.errorbar(np.arange(Lx), ex_ey_mean[0], ex_ey_err[0])
plt.yscale("log")

# %%
ey_ey_mean=np.loadtxt(directory+ensemble_id+"_ey_ey_mean.dat")
ey_ey_err =np.loadtxt(directory+ensemble_id+"_ey_ey_err.dat")

# %%
plt.matshow(np.log(ey_ey_mean))

# %%
plt.errorbar(np.arange(Lx), ey_ey_mean[0], ey_ey_err[0])
plt.yscale("log")
